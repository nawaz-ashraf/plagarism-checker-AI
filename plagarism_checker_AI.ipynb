# %%
import pandas as pd
df = pd.read_csv("train_snli.csv")

# %%
# Manually inspect the first few raw lines of the dataset
with open('train_snli.csv', 'r', encoding='utf-8') as file:
    raw_lines = [next(file) for _ in range(367372
                                           )]

# Display the raw lines
raw_lines
# Out:
# ['"A person on a horse jumps over a broken down airplane.\tA person is at a diner, ordering an omelette.\t0"\n',
#  '"A person on a horse jumps over a broken down airplane.\tA person is outdoors, on a horse.\t1"\n',
#  '"Children smiling and waving at camera\tThere are children present\t1"\n',
#  '"Children smiling and waving at camera\tThe kids are frowning\t0"\n',
#  '"A boy is jumping on skateboard in the middle of a red bridge.\tThe boy skates down the sidewalk.\t0"\n',
#  '"A boy is jumping on skateboard in the middle of a red bridge.\tThe boy does a skateboarding trick.\t1"\n',
#  '"An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.\tA boy flips a burger.\t0"\n',
#  '"Two blond women are hugging one another.\tThe women are sleeping.\t0"\n',
#  '"Two blond women are hugging one another.\tThere are women showing affection.\t1"\n',
#  '"A few people in a restaurant setting, one of them is drinking orange juice.\tThe people are sitting at desks in school.\t0"\n',
#  '"A few people in a restaurant setting, one of them is drinking orange juice.\tThe diners are at a restaurant.\t1"\n',
#  '"An older man is drinking orange juice at a restaurant.\tA man is drinking juice.\t1"\n',
#  '"An older man is drinking orange juice at a restaurant.\tTwo women are at a restaurant drinking wine.\t0"\n',
#  '"A man with blond-hair, and a brown shirt drinking out of a public water fountain.\tA blond man wearing a brown shirt is reading a book on a bench in the park\t0"\n',
#  '"A man with blond-hair, and a brown shirt drinking out of a public water fountain.\tA blond man drinking water from a fountain.\t1"\n',
#  '"Two women who just had lunch hugging and saying goodbye.\tThe friends scowl at each other over a full dinner table.\t0"\n',
#  '"Two women who just had lunch hugging and saying goodbye.\tThere are two woman in this picture.\t1"\n',
#  '"Two women, holding food carryout containers, hug.\tTwo groups of rival gang members flipped each other off.\t0"\n',
#  '"Two women, holding food carryout containers, hug.\tTwo women hug each other.\t1"\n',
#  '"A Little League team tries to catch a runner sliding into a base in an afternoon game.\tA team is trying to tag a runner out.\t1"\n',
#  '"A Little League team tries to catch a runner sliding into a base in an afternoon game.\tA team is playing baseball on Saturn.\t0"\n',
#  '"The school is having a special event in order to show the american culture on how other cultures are dealt with in parties.\tA school hosts a basketball game.\t0"\n',
#  '"The school is having a special event in order to show the american culture on how other cultures are dealt with in parties.\tA school is hosting an event.\t1"\n',
#  '"High fashion ladies wait outside a tram beside a crowd of people in the city.\tThe women do not care what clothes they wear.\t0"\n',
#  '"High fashion ladies wait outside a tram beside a crowd of people in the city.\tWomen are waiting by a tram.\t1"\n',
#  '"A man, woman, and child enjoying themselves on a beach.\tA family of three is at the beach.\t1"\n',
#  '"A man, woman, and child enjoying themselves on a beach.\tA family of three is at the mall shopping.\t0"\n',
#  '"People waiting to get on a train or just getting off.\tThere are people just getting on a train\t1"\n',
#  '"People waiting to get on a train or just getting off.\tThere are people waiting on a train.\t1"\n',
#  '"A couple playing with a little boy on the beach.\tA couple are playing with a young child outside.\t1"\n',
#  '"A couple playing with a little boy on the beach.\tA couple watch a little girl play by herself on the beach.\t0"\n',
#  '"A couple play in the tide with their young son.\tThe family is sitting down for dinner.\t0"\n',
#  '"A couple play in the tide with their young son.\tThe family is outside.\t1"\n',
#  '"A man and a woman cross the street in front of a pizza and gyro restaurant.\tThe people are standing still on the curb.\t0"\n',
#  '"A man and a woman cross the street in front of a pizza and gyro restaurant.\tNear a couple of restaurants, two people walk across the street.\t1"\n',
#  '"A woman in a green jacket and hood over her head looking towards a valley.\tThe woman is nake.\t0"\n',
#  '"A woman in a green jacket and hood over her head looking towards a valley.\tThe woman is wearing green.\t1"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThey are protesting outside the capital.\t0"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tA woman in white.\t1"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tA man is advertising for a restaurant.\t1"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThe woman is wearing black.\t0"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThe woman is wearing white.\t1"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tOlympic swimming.\t0"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tA man and a soman are eating together at John\'s Pizza and Gyro.\t0"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThey are walking with a sign.\t1"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThe man is sitting down while he has a sign for John\'s Pizza and Gyro in his arms.\t0"\n',
#  '"Woman in white in foreground and a man slightly behind walking with a sign for John\'s Pizza and Gyro in the background.\tThe woman and man are outdoors.\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo adults run across the street to get away from a red shirted person chasing them.\t0"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tThe adults are both male and female.\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo adults swimming in water\t0"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo adults walk across a street.\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo people ride bicycles into a tunnel.\t0"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo people walk away from a restaurant across a street.\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tSome people board a train.\t0"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo adults walk across the street.\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tTwo adults walking across a road\t1"\n',
#  '"Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground.\tThere are no women in the picture.\t0"\n',
#  '"A woman wearing all white and eating, walks next to a man holding a briefcase.\tA married couple is sleeping.\t0"\n',
#  '"A woman wearing all white and eating, walks next to a man holding a briefcase.\tA female is next to a man.\t1"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tNobody has food.\t0"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tA woman eats a banana and walks across a street, and there is a man trailing behind her.\t1"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tThe woman and man are playing baseball together.\t0"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tA woman eats ice cream walking down the sidewalk, and there is another woman in front of her with a purse.\t0"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tA person eating.\t1"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\ta woman eating a banana crosses a street\t1"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\ta woman sits for lunch\t0"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tthe woman is having coffee at the cafe\t0"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tThe woman is eating a banana.\t1"\n',
#  '"A woman is walking across the street eating a banana, while a man is following with his briefcase.\tthe woman is outside\t1"\n',
#  '"A skier slides along a metal rail.\tA skier is near the rail.\t1"\n',
#  '"A skier slides along a metal rail.\tA skier is away from the rail.\t0"\n',
#  '"A person on skis on a rail at night.\tThe woman eats a car\t0"\n',
#  '"A person on skis on a rail at night.\tThe person skiis\t1"\n',
#  '"A skier in electric green on the edge of a ramp made of metal bars.\tThe brightly dressed skier slid down the race course.\t1"\n',
#  '"A skier in electric green on the edge of a ramp made of metal bars.\tThe jogger ran through the streets.\t0"\n',
#  '"A yellow uniformed skier is performing a trick across a railed object.\tA snowboarder is riding a ski lift.\t0"\n',
#  '"A yellow uniformed skier is performing a trick across a railed object.\tSomebody is engaging in winter sports.\t1"\n',
#  '"A blond man is drinking from a public fountain.\tThe man is drinking water.\t1"\n',
#  '"A blond man is drinking from a public fountain.\tThe man is drinking coffee.\t0"\n',
#  '"Wet brown dog swims towards camera.\tThe dog is sleeping in his bed.\t0"\n',
#  '"Wet brown dog swims towards camera.\tA dog is in the water.\t1"\n',
#  '"Closeup image of a dog swimming.\tA cat reluctantly takes a bath.\t0"\n',
#  '"Closeup image of a dog swimming.\tA dog swims in a body of water.\t1"\n',
#  '"The furry brown dog is swimming in the ocean.\tA dog is swimming.\t1"\n',
#  '"The furry brown dog is swimming in the ocean.\tA dog is running around the yard.\t0"\n',
#  '"A big brown dog swims towards the camera.\tA dog is chasing a stick.\t0"\n',
#  '"A big brown dog swims towards the camera.\tA dog swims towards the camera.\t1"\n',
#  '"A man wearing black with a gray hat, holding a pitchfork, directs a horse-drawn cart.\tThe man with the gray hat and pitchfork is directing the cart.\t1"\n',
#  '"A man wearing black with a gray hat, holding a pitchfork, directs a horse-drawn cart.\tThe woman in a blue dress is hitching a horse to a cart.\t0"\n',
#  '"A man is leading a Clydesdale up a hay road, within a Old Country.\tA man is walking with his horse up a country road.\t1"\n',
#  '"A man is leading a Clydesdale up a hay road, within a Old Country.\tA woman in a gray business suit is drinking tea.\t0"\n',
#  '"A farmer fertilizing his garden with manure with a horse and wagon.\tThe man is fertilizering his garden.\t1"\n',
#  '"A farmer fertilizing his garden with manure with a horse and wagon.\tThe man is on the city street with his horse and wagon.\t0"\n',
#  '"A white horse is pulling a cart while a man stands and watches.\tAn animal is walking outside.\t1"\n',
#  '"A white horse is pulling a cart while a man stands and watches.\tA man is watching a horse race.\t0"\n',
#  '"A small group of church-goers watch a choir practice.\tA group watches a practice.\t1"\n',
#  '"A small group of church-goers watch a choir practice.\tA choir performs in front of packed crowd.\t0"\n',
#  '"A dog drops a red disc on a beach.\ta dog catch the ball on a beach\t0"\n',
#  '"A dog drops a red disc on a beach.\ta dog drops a red disc\t1"\n',
#  '"A man and a woman are walking on a street at the top of a hill.\tA man and woman walk on a street.\t1"\n',
#  '"A man and a woman are walking on a street at the top of a hill.\tTwo men play catch on a hill.\t0"\n',
#  '"An elderly man is drinking orange juice at a cafe.\tAn elderly man is drinking apple juice at a bar.\t0"\n',
#  '"An elderly man is drinking orange juice at a cafe.\tAn old man is enjoying a beverage at a cafe.\t1"\n',
#  '"A couple holding hands walks down a street.\tThere are people sitting on the side of the road.\t0"\n',
#  '"A couple holding hands walks down a street.\tPeople are holding hands and walking.\t1"\n',
#  '"A couple walk through a white brick town.\tPeople are walking outdoors.\t1"\n',
#  '"A couple walk through a white brick town.\tA man and woman walk in a brown brick city.\t0"\n',
#  '"Children going home from school.\tThe children are at the library.\t0"\n',
#  '"Children going home from school.\tThe school children head home.\t1"\n',
#  '"People listening to a choir in a Catholic church.\tPeople are listening to a metal band.\t0"\n',
#  '"People listening to a choir in a Catholic church.\tChoir singing in mass.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tA bicyclist is sitting down having lunch at the mall.\t0"\n',
#  '"Bicyclists waiting at an intersection.\tThe bicyclists are outside.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tThe bicycles are on a road.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tA person on a bike is near a street.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tBikers stop and wait for traffic at the intersection.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tThe bicyclists ride through the mall on their bikes.\t0"\n',
#  '"Bicyclists waiting at an intersection.\tBicyclists waiting their turn to cross.\t1"\n',
#  '"Bicyclists waiting at an intersection.\tBicyclists riding along a freeway.\t0"\n',
#  '"Bicyclists waiting at an intersection.\tThe bicyclists are dead.\t0"\n',
#  '"Bicyclists waiting at an intersection.\tThe bicyclists are at home.\t0"\n',
#  '"People waiting at a light on bikes.\tA bunch of friends are on a boat\t0"\n',
#  '"People waiting at a light on bikes.\tPeople with bikes.\t1"\n',
#  '"People waiting at a light on bikes.\tThe people are inside waiting.\t0"\n',
#  '"People waiting at a light on bikes.\tThere are some people outside.\t1"\n',
#  '"People waiting at a light on bikes.\tPeople are on their bikes.\t1"\n',
#  '"People waiting at a light on bikes.\tThe people are on bikes.\t1"\n',
#  '"People waiting at a light on bikes.\tThe people are running a red light.\t0"\n',
#  '"People waiting at a light on bikes.\tPeople in a car race.\t0"\n',
#  '"People waiting at a light on bikes.\tMen and women outside on a street corner.\t1"\n',
#  '"People waiting at a light on bikes.\tA ladybug has landed on a beautiful pink rose.\t0"\n',
#  '"People on bicycles waiting at an intersection.\tThe people are on skateboards.\t0"\n',
#  '"People on bicycles waiting at an intersection.\tPeople are riding their bicycles.\t1"\n',
#  '"People on bicycles waiting at an intersection.\tPeople wait on traffic.\t1"\n',
#  '"People on bicycles waiting at an intersection.\tPeople are waiting on foot.\t0"\n',
#  '"People on bicycles waiting at an intersection.\tThere are bicyclists stopped at a road.\t1"\n',
#  '"People on bicycles waiting at an intersection.\tThe people are sleeping.\t0"\n',
#  '"People on bicycles waiting at an intersection.\tThe people are waiting for the movie to begin.\t0"\n',
#  '"People on bicycles waiting at an intersection.\tMore than one person on a bicycle is obeying traffic laws.\t1"\n',
#  '"People on bicycles waiting at an intersection.\tThere are people on bicycles.\t1"\n',
#  '"People on bicycles waiting at an intersection.\tPeople on bicycles speed through an intersection.\t0"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tThe cart is empty.\t0"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA man is giving another man a piggyback ride.\t0"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA cart is full of items.\t1"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA man is sleeping under a bench.\t0"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA man watches another man.\t1"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tSomeone is on top of a cart full of items, while someone else observes.\t1"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tThe man is watching a woman.\t0"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA man is standing on top of a cart.\t1"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tThe cart is filled to the top.\t1"\n',
#  '"A man with a red shirt is watching another man who is standing on top of a attached cart filled to the top.\tA man eats octopus.\t0"\n',
#  '"A boy is drinking out of a water fountain shaped like a woman.\tA male is getting a drink of water.\t1"\n',
#  '"A boy is drinking out of a water fountain shaped like a woman.\tA man is drinking lemonade from a glass.\t0"\n',
#  '"three bikers stop in town.\tBikers stop in towns\t1"\n',
#  '"three bikers stop in town.\tA town has witnessed the arrival of three bikers.\t1"\n',
#  '"three bikers stop in town.\tThree bikers are going 100 mph\t0"\n',
#  '"three bikers stop in town.\tThe bikers breathe water\t0"\n',
#  '"three bikers stop in town.\tBikers stop for gas\t1"\n',
#  '"three bikers stop in town.\tThere is a very angry dog.\t0"\n',
#  '"three bikers stop in town.\tThe bikers are in the town.\t1"\n',
#  '"three bikers stop in town.\tA group of bikers are in the street.\t1"\n',
#  '"three bikers stop in town.\tThe bikers didn\'t stop in the town.\t0"\n',
#  '"three bikers stop in town.\tFive bikers are riding on the road.\t0"\n',
#  '"Two people loading brush on a trailer attached to a truck.\tA man is carrying a canoe to the water.\t0"\n',
#  '"Two people loading brush on a trailer attached to a truck.\tA couple of people are loading brush onto a trailer that is attached to a truck.\t1"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\ta bearded man pulls a rope\t1"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tA man pulls on a rope.\t1"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\ta man pulls his beard\t0"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\ta bearded man is pulling a car with his teeth.\t0"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tThe man was clean shaven.\t0"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tA bearded man is pulling on a rope.\t1"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tA man in a swimsuit, swings on a rope.\t0"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tA man is wearing a black shirt\t0"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tA man is pulling on a rope.\t1"\n',
#  '"A man with a beard, wearing a red shirt with gray sleeves and work gloves, pulling on a rope.\tThe man is able to grow a beard.\t1"\n',
#  '"A man with facial hair and a red and gray shirt tugging on a piece of rope.\tA man is naked on the bed.\t0"\n',
#  '"A man with facial hair and a red and gray shirt tugging on a piece of rope.\tA man has facial hair.\t1"\n',
#  '"A middle-aged oriental woman in a green headscarf and blue shirt is flashing a giant smile.\tThe middle aged oriental woman is watchingt v\t0"\n',
#  '"A middle-aged oriental woman in a green headscarf and blue shirt is flashing a giant smile.\tA middle aged oriental woman in a green headscarf and blue shirt is flashing a giant smile\t1"\n',
#  '"An Asian woman in a blue top and green headscarf smiling widely as another woman rows a boat in the background.\tAn Asian woman is smiling at while another lady is rowing.\t1"\n',
#  '"An Asian woman in a blue top and green headscarf smiling widely as another woman rows a boat in the background.\tAn Asian woman is running from a dog.\t0"\n',
#  '"A boat worker securing line.\tA worker is doing something to a boat.\t1"\n',
#  '"A boat worker securing line.\tThe boat worker is swimming in the ocean.\t0"\n',
#  '"A small girl with a necklace is swimming.\tA fat girl is diving off the edge\t0"\n',
#  '"A small girl with a necklace is swimming.\tA small girl with a necklace is in the water\t1"\n',
#  '"a skateboarder skates in the pool.\tA skate swims in the pool.\t0"\n',
#  '"a skateboarder skates in the pool.\tA skater is in the pool.\t1"\n',
#  '"A couple, who appear to be Indian or Pakistani, walk on a path beside a body of water, the mother carrying a child in a diaper, the father wrapped in a blanket with the logo of the humanitarian organization ""Save the Children.""\tA man is wrapped in a UNICEF blanket.\t0"\n',
#  '"A couple, who appear to be Indian or Pakistani, walk on a path beside a body of water, the mother carrying a child in a diaper, the father wrapped in a blanket with the logo of the humanitarian organization ""Save the Children.""\tA couple carrying a child are walking along water.\t1"\n',
#  '"There is a woman holding a baby, along with a man with a save the children bag.\tA group of people are possing for an add.\t1"\n',
#  '"There is a woman holding a baby, along with a man with a save the children bag.\tA man is watching an airplane.\t0"\n',
#  '"A family with a baby, the father is wearing a save the children sign.\tThree adults are pictured.\t0"\n',
#  '"A family with a baby, the father is wearing a save the children sign.\tA man is wearing something with writing on it.\t1"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tthey are riding a bike\t0"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA foreign family walks by a dirt trail along a body of water.\t1"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tThe family is admiring the water\t1"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tThe people are driving a car on the freeway.\t0"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA family of foreigners swims in the water.\t0"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA group of locals run on a dirt trail next to a frozen stream.\t0"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA family of foreigners walks by the water.\t1"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA family walks along a dirt path.\t1"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tA family plays board games at their dinner table.\t0"\n',
#  '"A foreign family is walking along a dirt path next to the water.\tThere is a family taking a walk outside.\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tPeople are looking at sculptures at a museum.\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tThere are people next to sculptures.\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tPeople standing near sculptures\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tThree people are looking at painting at a school fair.\t0"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tNobody is standing.\t0"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tA man and a woman are standing.\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tThe is a single sculpture.\t0"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tThe man and woman are standing by a swimming pool.\t0"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tThere are scultupres nearby.\t1"\n',
#  '"A man and a woman are standing next to sculptures, talking while another man looks at other sculptures.\tA man and a woman are sitting.\t0"\n',
#  '"Group of young women in dresses strolling on the sidewalk.\tall the young girls won the first prize\t0"\n',
#  '"Group of young women in dresses strolling on the sidewalk.\tthere are some groups one of them of young females are in dresses strolling for a ramp walk\t1"\n',
#  '"A man wearing a striped top and jeans does a skateboard trick on some steps while a man who is hunched over photographs him.\ta man is photographing a man skateboarding.\t1"\n',
#  '"A man wearing a striped top and jeans does a skateboard trick on some steps while a man who is hunched over photographs him.\ta man is riding his scooter alone\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man is taking the picture of a skateboarder who is being taken by aliens.\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tPhotographers capture a male skateboarder performing tricks inside an abandoned building.\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA woman is skateboarding with her boyfriend.\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man is taking the picture of a skateboarder who is performing a trick.\t1"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man photographs a wedding.\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man is taking photos of skateboarding tricks.\t1"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tPeople take photos outdoors while a man performs exciting skateboarding tricks.\t1"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man is photographing another man.\t1"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tTwo men are going down a water slide.\t0"\n',
#  '"A man squatting in the foreground of a photograph while taking a photograph of his own of a man doing a skateboarding kick flip in midair above a short flight of stairs outdoors.\tA man photographs a skateboarder doing tricks.\t1"\n',
#  '"One biker is running with their bike while another is riding around them.\tThe people are driving cars\t0"\n',
#  '"One biker is running with their bike while another is riding around them.\tPeople have bikes\t1"\n',
#  '"Two people with bicycles, one in front running with a bike and one in back riding.\tTwo people eating ice cream cones at the mall.\t0"\n',
#  '"Two people with bicycles, one in front running with a bike and one in back riding.\tOne person running next to their bike with the person riding their bike behind them.\t1"\n',
#  '"A young man doing a trick on a skateboard down the stairs while being photographed.\tA young man roller blades across a ramp while being photographed.\t0"\n',
#  '"A young man doing a trick on a skateboard down the stairs while being photographed.\tA man being photographed while he does a trick on his skateboard down the stairs.\t1"\n',
#  '"A lady in a black and white striped shirt and holding a bouquet of flowers, looks seriously at two gentlemen talking on the steps.\tA lady with a serious face is standing with two guys in front of steps outside.\t1"\n',
#  '"A lady in a black and white striped shirt and holding a bouquet of flowers, looks seriously at two gentlemen talking on the steps.\tThree guys are standing indoors with flowers in their hands.\t0"\n',
#  '"A man walking proudly down the street.\tThe man is in the theatre watching Avatar.\t0"\n',
#  '"A man walking proudly down the street.\tA man is outside.\t1"\n',
#  '"Four teenage boys are doing cannonballs into a swimming pool.\tA group of young men are splashing a lot of water.\t1"\n',
#  '"Four teenage boys are doing cannonballs into a swimming pool.\tSome boys are eating pizza in a restaurant.\t0"\n',
#  '"Three men standing on grass by the water looking at something on a table.\tThe three men are outside.\t1"\n',
#  '"Three men standing on grass by the water looking at something on a table.\tThe three men are indoors playing Foosball.\t0"\n',
#  '"A woman stands behind an outdoor grill with a blue basket of food in her hands.\tA woman standing behind a grill outside with a blue basket of food in her hands.\t1"\n',
#  '"A woman stands behind an outdoor grill with a blue basket of food in her hands.\tA woman holding a blue basket full of easter eggs outside of a church.\t0"\n',
#  '"A Land Rover makes its way through a deep pond.\tA car is in the shop.\t0"\n',
#  '"A Land Rover makes its way through a deep pond.\tA car drives through the water.\t1"\n',
#  '"many people relax in the yard.\tA group of people are outside.\t1"\n',
#  '"many people relax in the yard.\tPeople watch tv in their living room.\t0"\n',
#  '"A car sinking in water.\tA car is flooding.\t1"\n',
#  '"A car sinking in water.\tA truck drives down a country road in the sunshine.\t0"\n',
#  '"A man wearing black is playing an electric guitar at a concert.\tA man is playing the guitar.\t1"\n',
#  '"A man wearing black is playing an electric guitar at a concert.\tA man is playing the piano.\t0"\n',
#  '"A man with wild hair rocks a show playing a guitar center stage.\tThe bald man played the drums.\t0"\n',
#  '"A man with wild hair rocks a show playing a guitar center stage.\tA guy stands on stage with his guitar.\t1"\n',
#  '"woman and child on trolley car labeled Powell and market and bay and taylor\tThe woman is on a trolley.\t1"\n',
#  '"woman and child on trolley car labeled Powell and market and bay and taylor\tThe woman and child are on a subway train.\t0"\n',
#  '"Two female medical professionals, one african american& one white, looking over paperwork in a hospital.\tCoworkers left work and are driving to lunch.\t0"\n',
#  '"Two female medical professionals, one african american& one white, looking over paperwork in a hospital.\tThere are people at work.\t1"\n',
#  '"Two ladies are reading through binders.\tThe girls are watching a movie.\t0"\n',
#  '"Two ladies are reading through binders.\tSome women are reading.\t1"\n',
#  '"A man in the distance is walking past a brick wall painted with words and graffiti.\tA man sits and reads the graffiti on a wall.\t0"\n',
#  '"A man in the distance is walking past a brick wall painted with words and graffiti.\tGrafffiti on a brick wall.\t1"\n',
#  '"A woman and a child holding on to the railing while on trolley.\tThe people are not holding onto anything.\t0"\n',
#  '"A woman and a child holding on to the railing while on trolley.\tThe people are holding onto the rail.\t1"\n',
#  '"A man in a striped polo shirt is pointing and smiling.\tThe man is swimming\t0"\n',
#  '"A man in a striped polo shirt is pointing and smiling.\tThe man seems happy\t1"\n',
#  '"A guy performing a bicycle jump trick for an audience.\ttony hawk is performing a skating trick\t0"\n',
#  '"A guy performing a bicycle jump trick for an audience.\ta guy is performing a bike trick\t1"\n',
#  '"A gray-haired woman in a blue dress coat with snowflakes on it balances something on her head.\tThe woman is wearing a coat.\t1"\n',
#  '"A gray-haired woman in a blue dress coat with snowflakes on it balances something on her head.\tThe woman loves her blonde hair.\t0"\n',
#  '"Two children play outside in a field.\tKids are playing outdoors.\t1"\n',
#  '"Two children play outside in a field.\tTwo children are reading at their desks.\t0"\n',
#  '"One man sits inside and plays the banjo, there are trees behind him outside.\tA man runs outside.\t0"\n',
#  '"One man sits inside and plays the banjo, there are trees behind him outside.\tA male sitting indoors.\t1"\n',
#  '"Two children, in colorful outfits, playing in a field with a big rock in the middle.\tDon\'t play with rocks\t0"\n',
#  '"Two children, in colorful outfits, playing in a field with a big rock in the middle.\tTwo kids are playing with a big rock in the field\t1"\n',
#  '"Two young girls are playing outside in a non-urban environment.\tTwo girls are playing outside.\t1"\n',
#  '"Two young girls are playing outside in a non-urban environment.\tSome girls are running on the sidewalk, next to some parked cars.\t0"\n',
#  '"Two children in hats play in an open, rocky field.\tThe children are at home eating lunch.\t0"\n',
#  '"Two children in hats play in an open, rocky field.\tThe children are playing in a rocky field.\t1"\n',
#  '"A woman wearing a green and pink dress is dancing with someone wearing a blue top with white pants.\tThe woman in green and pink is dancing.\t1"\n',
#  '"A woman wearing a green and pink dress is dancing with someone wearing a blue top with white pants.\tThe dancing woman is alone in her bedroom.\t0"\n',
#  '"Man in gold pants looking at the camera.\tMan looking at the camera.\t1"\n',
#  '"Man in gold pants looking at the camera.\tMan is walking away to the hall.\t0"\n',
#  '"A man in a gold skirt sits in front of the computer.\tA man in a gold skirt sitting at his computer watching the computer screen.\t1"\n',
#  '"A man in a gold skirt sits in front of the computer.\tA man in blue pants sitting and watching the television.\t0"\n',
#  '"Man wearing black t-shirt sitting at a computer desk.\tthe man is working on the computer\t1"\n',
#  '"Man wearing black t-shirt sitting at a computer desk.\tthe man called off work and was at the zoo all day\t0"\n',
#  '"A bearded man in a black t-shirt sits in front of a desk holding a computer.\tA man is standing in the rain.\t0"\n',
#  '"A bearded man in a black t-shirt sits in front of a desk holding a computer.\tA man waiting with his computer.\t1"\n',
#  '"A man in a gold foils skirt, sitting at a computer desk, looks at the camera with his hands raised to his face.\ta man is looking at his webcam\t1"\n',
#  '"A man in a gold foils skirt, sitting at a computer desk, looks at the camera with his hands raised to his face.\ta man is sticking his tongue out\t0"\n',
#  '"A young girl sitting at a table with a bowl on her head\tA young girl has a bowl on her head\t1"\n',
#  '"A young girl sitting at a table with a bowl on her head\tA man is eating cereal in his car\t0"\n',
#  '"A man dances with a fire baton at night.\tthe woman does a hula dance\t0"\n',
#  '"A man dances with a fire baton at night.\tthe man is dancing\t1"\n',
#  '"A doctor checks the stomach of a toddler.\tThe toddler is getting a checkup.\t1"\n',
#  '"A doctor checks the stomach of a toddler.\tThe doctor is looking inside the toddler\'s mouth.\t0"\n',
#  '"Young blond woman putting her foot into a water fountain\tA young blond woman is sitting down on a beach chair.\t0"\n',
#  '"Young blond woman putting her foot into a water fountain\tA person is dipping her foot into water.\t1"\n',
#  '"A young woman tries to stick her foot in a fountain.\tThe woman is riding a train.\t0"\n',
#  '"A young woman tries to stick her foot in a fountain.\tA woman is near a fountain.\t1"\n',
#  '"A young woman tries to stick her foot in a fountain.\tThe woman has one foot in the air.\t1"\n',
#  '"A woman in capri jeans crouches on the edge of a fountain with her left foot kicked out to touch the falling water.\tA woman is walking in park\t0"\n',
#  '"A woman in capri jeans crouches on the edge of a fountain with her left foot kicked out to touch the falling water.\tA woman is like to touch the water in fountain\t1"\n',
#  '"Woman balancing on edge of fountain while sticking her toe in the water.\tA woman stand on a fountain and dips her toes in.\t1"\n',
#  '"Woman balancing on edge of fountain while sticking her toe in the water.\tA woman sits on the grassy ground.\t0"\n',
#  '"A couple strolls arm and arm and hand in hand down a city sidewalk.\tThe couple is outdoors.\t1"\n',
#  '"A couple strolls arm and arm and hand in hand down a city sidewalk.\tThe couple is having dinner at a restaurant.\t0"\n',
#  '"A man stare at a passing couple while walking down the block.\tA man stares at a passing couple.\t1"\n',
#  '"A man stare at a passing couple while walking down the block.\tThe woman stares at a couple as they argue down the block.\t0"\n',
#  '"a couple are holding hands behind their backs while walking down a street, and the man has his arm around her shoulder.\tcouple walking\t1"\n',
#  '"a couple are holding hands behind their backs while walking down a street, and the man has his arm around her shoulder.\tbear in zoo\t0"\n',
#  '"A man and a woman are holding hands as they walk along a city sidewalk.\tA married couple are fighting on the sidewalk.\t0"\n',
#  '"A man and a woman are holding hands as they walk along a city sidewalk.\tA man and a woman are holding hands.\t1"\n',
#  '"a man in red stands with his child at the beach.\tA man wearing blue sleeping with his child in his lap inside his home.\t0"\n',
#  '"New sport is being played to show appreciation to the kids who can not walk.\tPeople are playing a sport in honor of crippled people.\t1"\n',
#  '"New sport is being played to show appreciation to the kids who can not walk.\tPeople are playing football without gear.\t0"\n',
#  '"Two men in wheelchairs are reaching in the air for a basketball.\tTwo people in wheelchairs are reaching in the air for a basketball.\t1"\n',
#  '"Two men in wheelchairs are reaching in the air for a basketball.\tTwo women in wheelchairs are reaching in the air for a basketball.\t0"\n',
#  '"Three wheelchair basketball players wearing team uniforms are attempting to reach the descending basketball with other players in the background.\tThree wheelchair basketball players playing basketball in field.\t1"\n',
#  '"Three wheelchair basketball players wearing team uniforms are attempting to reach the descending basketball with other players in the background.\tA peoples are taking coffee together at coffeshop.\t0"\n',
#  '"Four guys in wheelchairs on a basketball court two are trying to grab a basketball in midair.\tFour guys are playing cards.\t0"\n',
#  '"Four guys in wheelchairs on a basketball court two are trying to grab a basketball in midair.\tFour guys are playing basketball.\t1"\n',
#  '"Three dogs in different shades of brown and white biting and licking each other.\tthe dogs are fighting\t0"\n',
#  '"Three dogs in different shades of brown and white biting and licking each other.\tthere are three dogs\t1"\n',
#  '"Two dogs playfully bite a third dog, which has its tongue sticking out.\tTwo dogs are sleeping while a third eats its food.\t0"\n',
#  '"Two dogs playfully bite a third dog, which has its tongue sticking out.\tA pair of dogs tease a third with nibbles.\t1"\n',
#  '"Three small puppies bite and play together in the grass.\tThe puppies are sleeping in a basket.\t0"\n',
#  '"Three small puppies bite and play together in the grass.\tThree puppies are playing outside.\t1"\n',
#  '"Two dogs biting another dog in a field.\tdogs attacking another dog\t1"\n',
#  '"Two dogs biting another dog in a field.\tdog sitting in filed\t0"\n',
#  '"Tourists waiting at a train stop.\tTourist walking around an art museum.\t0"\n',
#  '"Tourists waiting at a train stop.\tA group of tourist waiting for a train at a train station.\t1"\n',
#  '"A doctor in blue scrubs is performing an operation assisted by two men and a woman.\ta old man was talking\t1"\n',
#  '"A doctor in blue scrubs is performing an operation assisted by two men and a woman.\tthe boys were angry\t0"\n',
#  '"A woman with a black jacket walks past an outdoor movie poster.\tA woman walking outside.\t1"\n',
#  '"A woman with a black jacket walks past an outdoor movie poster.\tA woman is cleaning up.\t0"\n',
#  '"A man in an elf hat holding a white umbrella is standing on the sidewalk with two other men.\tA man stands.\t1"\n',
#  '"A man in an elf hat holding a white umbrella is standing on the sidewalk with two other men.\tMy love\'s like a red, red wig.\t0"\n',
#  '"Indian lady and a guy in a blue suit dancing in the sunlight.\tA woman eats a pickle.\t0"\n',
#  '"Indian lady and a guy in a blue suit dancing in the sunlight.\tTwo people dancing outdoors.\t1"\n',
#  '"Two older men are talking.\tTwo people are having a conversation.\t1"\n',
#  '"Two older men are talking.\tA crowd is talking over each other.\t0"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tA biker is doing jumps by trees.\t1"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThey aren\'t on bikes.\t0"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThe biker is jumping into a hole.\t1"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tA person rides a bike outdoors.\t1"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThere\'s a biker\t1"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThey are avoiding trees.\t1"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThe mountain biker is going on a desert trail.\t0"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tThe biker is trying to jump over a volcano.\t0"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tHe\'s indoors\t0"\n',
#  '"A mountain biker jumping a slope outdoors in a forest area.\tA person is riding in a bobsled.\t0"\n',
#  '"Two older men in winter coats talking outside of a shop with a grassy lawn covered in a light coat of snow in front of it.\tTwo old men in winter coats talk outside.\t1"\n',
#  '"Two older men in winter coats talking outside of a shop with a grassy lawn covered in a light coat of snow in front of it.\tThe old men are wearing raincoats.\t0"\n',
#  '"Two elderly men having a conversation, snow covered grass in the background.\tThe men are drinking coffee and having some cookies\t0"\n',
#  '"Two elderly men having a conversation, snow covered grass in the background.\tThe men are sleeping\t0"\n',
#  '"Two elderly men having a conversation, snow covered grass in the background.\tThere are two men outside in this picture\t1"\n',
#  '"Two men are standing outside and snow is on the ground.\tPeople are near snow.\t1"\n',
#  '"Two men are standing outside and snow is on the ground.\tMen making snow angels.\t0"\n',
#  '"Two older men in coats are standing outside.\tThese men never wore coats.\t0"\n',
#  '"Two older men in coats are standing outside.\tThey are outside wearing coats.\t1"\n',
#  '"A gentleman in a purple scarf and hat is looking at money while holding an accordion.\tA woman is brushing her hair in her bedroom.\t0"\n',
#  '"A gentleman in a purple scarf and hat is looking at money while holding an accordion.\tA man is holding an accordian.\t1"\n',
#  '"BMX biker jumps over a ravine.\tthere is a bmx biker who is perfect in ravine jumping\t1"\n',
#  '"BMX biker jumps over a ravine.\tanybody can do ravine jumping\t0"\n',
#  '"A white bike is tied to a street sign.\tthe car is parked at the sign\t0"\n',
#  '"A white bike is tied to a street sign.\tthe bike is tied to a sign\t1"\n',
#  '"A white bike is leaning against a post.\tA bike is on the ground about to be reparied\t0"\n',
#  '"A white bike is leaning against a post.\tA bike it outside\t1"\n',
#  '"The boy locked the cycle and went away.\tA boy riding a bike.\t0"\n',
#  '"The boy locked the cycle and went away.\tA boy walking away.\t1"\n',
#  '"A crowded city during daytime.\tA city filled with people in the middle of the daytime.\t1"\n',
#  '"A crowded city during daytime.\tA abandoned city at the edge of the world.\t0"\n',
#  '"People walking around in a big city.\tPeople are outside.\t1"\n',
#  '"People walking around in a big city.\tThe people are asleep.\t0"\n',
#  '"A busy city that looks like New York City.\tThe city has a lot of people in it.\t1"\n',
#  '"A busy city that looks like New York City.\tThe city looks like Lawrence, Kansas.\t0"\n',
#  '"A view of buildings and people walking across the streets in Times Square, New York City.\tThere is a city.\t1"\n',
#  '"A view of buildings and people walking across the streets in Times Square, New York City.\tThe field of poppies is perfectly still.\t0"\n',
#  '"A woman is making a clay pot.\tA man is painting a painting.\t0"\n',
#  '"A woman is making a clay pot.\tAn artist is sculpting with clay.\t1"\n',
#  '"A barber waiting for customers.\tA barber is at work.\t1"\n',
#  '"A barber waiting for customers.\tThe barber is closing the shop at the end of the day.\t0"\n',
#  '"A man sitting in a barber shop.\tThere is an individual waiting indoors.\t1"\n',
#  '"A man sitting in a barber shop.\tA man is brushing his teeth.\t0"\n',
#  '"A woman preparing to glaze a bowl.\tA woman not preparing to glaze\t0"\n',
#  '"A woman preparing to glaze a bowl.\tA woman preparing to glaze\t1"\n',
#  '"A woman wearing an apron inspects a large pot on a table filled with cups, bowls, pots and baskets of assorted size.\tA woman wearing gloves is washing dishes.\t0"\n',
# ...
#  '"A small girl dressed in a yellow dress with flowers on it bends over near a large pile of watermelons.\tThe girl is alone and asleep in her bedroom.\t0"\n',
#  '"A little girl picking up a watermelon from a pile.\tA girl is picking up an orange.\t0"\n',
#  '"A little girl picking up a watermelon from a pile.\tA girl is picking an item up.\t1"\n',
#  '"a young girl in a flowery dress surrounded by watermelons\tThere is a lot of fruit.\t1"\n',
#  '"a young girl in a flowery dress surrounded by watermelons\tThere are only potatoes.\t0"\n',
#  '"A man in a blue jacket screaming.\tA man is making a loud noise.\t1"\n',
#  '"A man in a blue jacket screaming.\tA man is whispering.\t0"\n',
#  '"Children playing a game in a field.\tAdults playing a game.\t0"\n',
#  '"Children playing a game in a field.\tChildren playing a game.\t1"\n',
#  '"A seated woman with short hair and a camera throws a Frisbee to a brown dog.\tThe woman throws a Frisbee to the dog.\t1"\n',
#  '"A seated woman with short hair and a camera throws a Frisbee to a brown dog.\tThe woman is chasing the dog that took her camera.\t0"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tPeople are in the street.\t1"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tThe Asian city is full of fields.\t0"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tThe Asian city is full of sights.\t1"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tPeople are in the street in Toronto.\t0"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tCity people in street\t1"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tA group of people are sitting in a field\t0"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tThere are people in an urban area.\t1"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tThere are people in front of buildings that are brightly lit.\t1"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tCity streetwalkers\t0"\n',
#  '"Asian city scene of people in street with bright lights and glass buildings behind.\tIt is an American city.\t0"\n',
#  '"A man is painting a portrait of an outside scene that includes a street sign with a bicycle chained to it.\tA woman is drawing a microorganism.\t0"\n',
#  '"A man is painting a portrait of an outside scene that includes a street sign with a bicycle chained to it.\tA man is painting a landscape of an outdoors area.\t1"\n',
#  '"An older man stands on the sidewalk painting the view.\tThe old man is painting a view of a bathroom.\t0"\n',
#  '"An older man stands on the sidewalk painting the view.\tThe old man is painting a portrait.\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tThe street is empty.\t0"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tThe buildings are tall.\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tNobody is on the street in Asia.\t0"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tThe crowds are at an indoor swimming meet.\t0"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tThe Seiko building is large.\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tlots of people are in the street\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tthere was a storm so nobody went outside\t0"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tThere is a crowded street.\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tA crowded street in Asia.\t1"\n',
#  '"A crowded street, in an Asian country, where the buildings are dominated by the Seiko building.\tA crowded street in America.\t0"\n',
#  '"A small boy has gotten into the cabinet and gotten flour and crisco all over himself.\tThe boy is playing the violin.\t0"\n',
#  '"A small boy has gotten into the cabinet and gotten flour and crisco all over himself.\tThe boy is making a mess.\t1"\n',
#  '"A male painting a scene in front of him.\tA person is painting.\t1"\n',
#  '"A male painting a scene in front of him.\tA girl is painting a self portrait.\t0"\n',
#  '"Busy Japanese intersection like maybe Tokyo.\tThere are no cars on the street.\t0"\n',
#  '"Busy Japanese intersection like maybe Tokyo.\tThere are lots of cars on the street.\t1"\n',
#  '"Cars are passing through a town.\tsome car passing outside\t1"\n',
#  '"Cars are passing through a town.\tCars are parked in the town.\t0"\n',
#  '"A picture of a city with a sign welcoming travelers on a busy street.\tA picture of a city is on a street\t1"\n',
#  '"A picture of a city with a sign welcoming travelers on a busy street.\tThe people are dancing\t0"\n',
#  '"Overlooking a street with a sign above shops that states Welcome To Golden.\tThe shop sign says  ""Welcome to Golden""\t1"\n',
#  '"Overlooking a street with a sign above shops that states Welcome To Golden.\tThe shop sign is laying on the sidewalk.\t0"\n',
#  '"There are cars driving down a street with a sign displaying Welcome to Golden.\tThe cars are parked in a showroom.\t0"\n',
#  '"There are cars driving down a street with a sign displaying Welcome to Golden.\tThe cars are outside.\t1"\n',
#  '"A main street scene of a small town with an overhead welcome sign that says ""Welcome to Golden"".\tA neon sign reads ""Now leaving Golden""\t0"\n',
#  '"A main street scene of a small town with an overhead welcome sign that says ""Welcome to Golden"".\tA sign reads ""Welcome to Golden""\t1"\n',
#  '"Little Girl in brown shirt and blue jean skirt dances on wood floor.\tA girl is dancing in a brown shirt and blue jean skirt on a wooden floor\t1"\n',
#  '"Little Girl in brown shirt and blue jean skirt dances on wood floor.\tPoop\'s on the floor while the girl dances\t0"\n',
#  '"A young man is performing a jump on a skateboard while another young man photographs his stunt.\tTwo boys are skateboarding outside.\t1"\n',
#  '"A young man is performing a jump on a skateboard while another young man photographs his stunt.\tTwo boys are riding bikes down the street.\t0"\n',
#  '"A young girl dancing in her socks on a wooden floor strewn with pink balloons.\tA girl is enjoying herself.\t1"\n',
#  '"A young girl dancing in her socks on a wooden floor strewn with pink balloons.\tThe girl seems very sad about the blue balloons.\t0"\n',
#  '"Child with pink strings on head dancing surrounded by confetti, balloons.\tA child is roller skating.\t0"\n',
#  '"Child with pink strings on head dancing surrounded by confetti, balloons.\tA child is dancing.\t1"\n',
#  '"A good-looking firefighter sets up ""Do Not Cross"" tape in the city.\tA firefighter is sleeping.\t0"\n',
#  '"A good-looking firefighter sets up ""Do Not Cross"" tape in the city.\tA firefighter sets up a do not cross\t1"\n',
#  '"A good-looking firefighter sets up ""Do Not Cross"" tape in the city.\tA firefighter sets up tape in a city\t1"\n',
#  '"A fireman protects an area by setting up a boundary while others watch.\tA fireman is working hard to keep people safe.\t1"\n',
#  '"A fireman protects an area by setting up a boundary while others watch.\tA fireman is trying to run away from the fire.\t0"\n',
#  '"The blond girl is dancing inside a house.\tThe girl is sitting on a bench in a park.\t0"\n',
#  '"The blond girl is dancing inside a house.\tA person is indoors.\t1"\n',
#  '"Two people standing in front of a large statue of a woman, other statues and busts visible in the background.\tTwo people waiting in line for food at a crowded restaurant.\t0"\n',
#  '"Two people standing in front of a large statue of a woman, other statues and busts visible in the background.\tTwo people standing standing near a large statue, with other states nearby.\t1"\n',
#  '"a man with a white covering is walking up a flight of stairs.\tAn old woman is falling down the stairs.\t0"\n',
#  '"a man with a white covering is walking up a flight of stairs.\tA human walks up some stairs.\t1"\n',
#  '"A family between a van and fence\tA family by a van.\t1"\n',
#  '"A family between a van and fence\tA family by a pickup truck.\t0"\n',
#  '"A woman talking to four little children outside.\tA female adult is near some kids.\t1"\n',
#  '"A woman talking to four little children outside.\tA teacher is reading a book in class.\t0"\n',
#  '"A mother with her four children.\tA man with his pets.\t0"\n',
#  '"A mother with her four children.\tA woman with children.\t1"\n',
#  '"A woman and a few children in an alleyway in between a vehicle and a fence.\tThe woman and children are in their dining room.\t0"\n',
#  '"A woman and a few children in an alleyway in between a vehicle and a fence.\tSeveral people in an alleyway.\t1"\n',
#  '"A woman in a floral dress talks to children in front of a van.\tA woman is talking to children.\t1"\n',
#  '"A woman in a floral dress talks to children in front of a van.\tA woman is screaming at her kid.\t0"\n',
#  '"Two men with heads down signing a paper.\tThe men jump off a bridge.\t0"\n',
#  '"Two men with heads down signing a paper.\tThe two men sign something.\t1"\n',
#  '"A man and a woman having an intimate conversation in front a statue.\tA couple are having a conversation\t1"\n',
#  '"A man and a woman having an intimate conversation in front a statue.\tA couple are having dinner in a restaurant.\t0"\n',
#  '"A man in a Tour De Force shirt is working on a bicycle.\tA woman is biking.\t0"\n',
#  '"A man in a Tour De Force shirt is working on a bicycle.\tA man is working on a bike.\t1"\n',
#  '"A young toddler wearing pink sandals is walking on hopscotch numbers.\tA grown man wearing pink sandals plays hopscotch.\t0"\n',
#  '"A young toddler wearing pink sandals is walking on hopscotch numbers.\tA baby walks on the ground.\t1"\n',
#  '"a man wearing blue plays soccer.\tman playing soccer\t1"\n',
#  '"a man wearing blue plays soccer.\tman playing basketball\t0"\n',
#  '"Mothers with children talking at a gathering.\tThe mothers are yelling at the children.\t0"\n',
#  '"Mothers with children talking at a gathering.\tThe mothers are having conversations.\t1"\n',
#  '"Two women are talking while children are sitting on their laps.\tThe man is painting a house.\t0"\n',
#  '"Two women are talking while children are sitting on their laps.\tSome women are talking.\t1"\n',
#  '"Two women, each embracing a little girl, catch up at a small family gathering.\t2 women are carrying little girls.\t1"\n',
#  '"Two women, each embracing a little girl, catch up at a small family gathering.\tThe women left their children behind.\t0"\n',
#  '"Two women holding children talking to one another.\tTwo women are running at the park looking for their children.\t0"\n',
#  '"Two women holding children talking to one another.\tThere are at least four people.\t1"\n',
#  '"Two women, each with a child, look at each other.\tThe women have no kids\t0"\n',
#  '"Two women, each with a child, look at each other.\tWomen are with their kids\t1"\n',
#  '"A black-and-white dog carries a stick in his mouth as he swims in the clear water.\tThe water is empty\t0"\n',
#  '"A black-and-white dog carries a stick in his mouth as he swims in the clear water.\tA dog is outside\t1"\n',
#  '"A black and white dog with a stick in its mouth is swimming.\tA dog with an object in it\'s mouth is in the water.\t1"\n',
#  '"A black and white dog with a stick in its mouth is swimming.\tA cat with a stick in its mouth is in a bathtub.\t0"\n',
#  '"A pirate is chasing a princess down the sidewalk.\tPirate doing the hokey pokey\t0"\n',
#  '"A pirate is chasing a princess down the sidewalk.\tPirate on the sidewalk\t1"\n',
#  '"A dog is fetching a stick out of very clear water.\tA dog is fetching a stick out of very clear water.\t1"\n',
#  '"A dog is fetching a stick out of very clear water.\tA dog is sleeping on the front porch.\t0"\n',
#  '"A dog in the water carries a stick in his mouth.\tA dog is going for a walk in the park.\t0"\n',
#  '"A dog in the water carries a stick in his mouth.\tA dog carries a stick in his mouth.\t1"\n',
#  '"Two children are running down a sidewalk dressed in costumes.\tKids are getting in a fight.\t0"\n',
#  '"Two children are running down a sidewalk dressed in costumes.\tTwo kids are running.\t1"\n',
#  '"1 little boy wearing a pirate costume following closely behind a little girl wearing a blue dress carrying a orange pumpkin bucket and walking down the sidewalk.\tBoy in costume followed by a girl in costume.\t1"\n',
#  '"1 little boy wearing a pirate costume following closely behind a little girl wearing a blue dress carrying a orange pumpkin bucket and walking down the sidewalk.\tA boy in a clown costume followed by a girl.\t0"\n',
#  '"A little boy in a pirate costume is running behind a little girl in a princess costume carrying an orange pumpkin along the sidewalk.\tThe kids are sitting in their desks during class.\t0"\n',
#  '"A little boy in a pirate costume is running behind a little girl in a princess costume carrying an orange pumpkin along the sidewalk.\tTwo kids wearing costumes are outside.\t1"\n',
#  '"A man with a gray shirt holds a young infant in his hands.\tA man is wearing a shirt.\t1"\n',
#  '"A man with a gray shirt holds a young infant in his hands.\tThe man has a yellow shirt.\t0"\n',
#  '"Two girls, each in a dress walking together.\tTwo girls slapped each other.\t0"\n',
#  '"Two girls, each in a dress walking together.\tTwo Girls are doing exercise.\t1"\n',
#  '"A group of people are sitting around a table under a blue sunshade.\tgirl plays nintendo\t0"\n',
#  '"A group of people are sitting around a table under a blue sunshade.\tpeople sit around table\t1"\n',
#  '"People in line for plates of rice.\tPeople are waiting to eat.\t1"\n',
#  '"People in line for plates of rice.\tPeople are sitting down eating.\t0"\n',
#  '"People sitting down to eat.\tPeople are about to eat.\t1"\n',
#  '"People sitting down to eat.\tPeople milling about after a concert.\t0"\n',
#  '"Several men sit outside on brick ledges built around tall trees.\tSome men are sitting outdoors.\t1"\n',
#  '"Several men sit outside on brick ledges built around tall trees.\tThe men are chopping down the trees.\t0"\n',
#  '"Workers are eating a meal while one man sits on a pile of plywood.\tWorkers are resting during a meal break.\t1"\n',
#  '"Workers are eating a meal while one man sits on a pile of plywood.\tWorkers are talking and sitting on metal beams.\t0"\n',
#  '"Workers are taking a break during midday.\tWorkers are diligently building a house.\t0"\n',
#  '"Workers are taking a break during midday.\tWorkers are on break.\t1"\n',
#  '"Workers are sitting next to a work zone eating food.\tthe workers are sitting eating food\t0"\n',
#  '"Workers are sitting next to a work zone eating food.\tthe workers are waiting for next work\t1"\n',
#  '"Biker riding dirt bike on dirt track\tHe is paddling a canoe.\t0"\n',
#  '"Biker riding dirt bike on dirt track\tHuman rides two wheeled vehicle.\t1"\n',
#  '"A motorcycle racer is in action at the track.\tThe racer is driving.\t1"\n',
#  '"A motorcycle racer is in action at the track.\tThe motorcycle racer is running\t0"\n',
#  '"A blond woman with her hair up is taking off a white sweatshirt.\tA woman is taking off a blue shirt.\t0"\n',
#  '"A blond woman with her hair up is taking off a white sweatshirt.\tA woman is blonde\t1"\n',
#  '"A person is a red hat and winter jacket is looking into the distance.\tThe person stares off into the distance.\t1"\n',
#  ...]

# %%
# Manually split the single column into multiple columns using tab ('\t') separator
df_fixed = df.iloc[:, 0].str.split("\t", expand=True)

# Assign correct column names based on expected dataset structure
df_fixed.columns = ["Premise", "Hypothesis", "Label"]

# Display the first few rows to confirm the fix
df_fixed.head()
# Out:
#                                              Premise  \
# 0  A person on a horse jumps over a broken down a...
# 1              Children smiling and waving at camera
# 2              Children smiling and waving at camera
# 3  A boy is jumping on skateboard in the middle o...
# 4  A boy is jumping on skateboard in the middle o...
#
#                             Hypothesis Label
# 0    A person is outdoors, on a horse.     1
# 1           There are children present     1
# 2                The kids are frowning     0
# 3    The boy skates down the sidewalk.     0
# 4  The boy does a skateboarding trick.     1

# %%
# Clean the data by removing extra quotation marks and stripping spaces
cleaned_lines = [line.replace('"', '').strip() for line in raw_lines]

# Split each line into columns using tab as the separator
processed_data = [line.split("\t") for line in cleaned_lines]

# Convert to a DataFrame with correct column names
df_cleaned = pd.DataFrame(processed_data, columns=["Premise", "Hypothesis", "Label"])

# Display the first few rows to confirm proper formatting
df_cleaned.head(10)
# Out:
#                                              Premise  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2              Children smiling and waving at camera
# 3              Children smiling and waving at camera
# 4  A boy is jumping on skateboard in the middle o...
# 5  A boy is jumping on skateboard in the middle o...
# 6  An older man sits with his orange juice at a s...
# 7           Two blond women are hugging one another.
# 8           Two blond women are hugging one another.
# 9  A few people in a restaurant setting, one of t...
#
#                                       Hypothesis Label
# 0  A person is at a diner, ordering an omelette.     0
# 1              A person is outdoors, on a horse.     1
# 2                     There are children present     1
# 3                          The kids are frowning     0
# 4              The boy skates down the sidewalk.     0
# 5            The boy does a skateboarding trick.     1
# 6                          A boy flips a burger.     0
# 7                        The women are sleeping.     0
# 8             There are women showing affection.     1
# 9     The people are sitting at desks in school.     0

# %%
# Convert the 'Label' column to integers
df_cleaned["Label"] = df_cleaned["Label"].astype(int)

# Define plagiarism detection labels
def label_to_plagiarism(label):
    return "Plagiarism Detected" if label in [0, 2] else "No Plagiarism Detected"

# Apply the function to create a new column
df_cleaned["Plagiarism_Status"] = df_cleaned["Label"].apply(label_to_plagiarism)

# Display the updated dataset
df_cleaned.head(10)
# Out:
#                                              Premise  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2              Children smiling and waving at camera
# 3              Children smiling and waving at camera
# 4  A boy is jumping on skateboard in the middle o...
# 5  A boy is jumping on skateboard in the middle o...
# 6  An older man sits with his orange juice at a s...
# 7           Two blond women are hugging one another.
# 8           Two blond women are hugging one another.
# 9  A few people in a restaurant setting, one of t...
#
#                                       Hypothesis  Label  \
# 0  A person is at a diner, ordering an omelette.      0
# 1              A person is outdoors, on a horse.      1
# 2                     There are children present      1
# 3                          The kids are frowning      0
# 4              The boy skates down the sidewalk.      0
# 5            The boy does a skateboarding trick.      1
# 6                          A boy flips a burger.      0
# 7                        The women are sleeping.      0
# 8             There are women showing affection.      1
# 9     The people are sitting at desks in school.      0
#
#         Plagiarism_Status
# 0     Plagiarism Detected
# 1  No Plagiarism Detected
# 2  No Plagiarism Detected
# 3     Plagiarism Detected
# 4     Plagiarism Detected
# 5  No Plagiarism Detected
# 6     Plagiarism Detected
# 7     Plagiarism Detected
# 8  No Plagiarism Detected
# 9     Plagiarism Detected

# %%
# Import necessary libraries for text processing and model training
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    df_cleaned[["Premise", "Hypothesis"]], df_cleaned["Plagiarism_Status"],
    test_size=0.2, random_state=42)

# Combine "Premise" and "Hypothesis" for similarity-based learning
X_train_combined = X_train["Premise"] + " " + X_train["Hypothesis"]
X_test_combined = X_test["Premise"] + " " + X_test["Hypothesis"]

# Build a text classification pipeline
pipeline = Pipeline([
    ("tfidf", TfidfVectorizer()),  # Convert text to numerical vectors
    ("classifier", LogisticRegression())  # Train logistic regression model
])

# Train the model
pipeline.fit(X_train_combined, y_train)

# Make predictions
y_pred = pipeline.predict(X_test_combined)

# Evaluate model accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print accuracy
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model Accuracy: 0.70

# %%
print(f"Final Logistic Regression Accuracy: {accuracy:.2f}")
# Out:
# Final Logistic Regression Accuracy: 0.70

# %%
import joblib

# Save the model
joblib.dump(pipeline, "plagiarism_detector.pkl")

print("✅ Model saved as plagiarism_detector.pkl")
# Out:
# ✅ Model saved as plagiarism_detector.pkl

# %%
# Load the saved model
model = joblib.load("plagiarism_detector.pkl")

# Example test case
test_premise = "A person is riding a horse."
test_hypothesis = "An individual is on an animal."

# Combine and predict
test_input = [test_premise + " " + test_hypothesis]
prediction = model.predict(test_input)[0]

print(f"🔍 Model Prediction: {'Plagiarism Detected' if prediction == 1 else 'No Plagiarism Detected'}")
# Out:
# 🔍 Model Prediction: No Plagiarism Detected
